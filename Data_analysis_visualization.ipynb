# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\vaibh\PycharmProjects\spark\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\vaibh\PycharmProjects\spark\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\vaibh\PycharmProjects\spark\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
pd.get_option("display.max_columns")
pd.set_option('max_colu', 30)
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('BankChurners.csv')
data.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',axis=1, inplace=True)
data.drop('Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',axis=1, inplace=True)
data.drop('CLIENTNUM', axis = 1, inplace=True)
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  object
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  object
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
# ...

# %%
def plot_design():
    plt.xlabel('')
    plt.ylabel('')
    plt.yticks(fontsize=13, color='black')
    plt.box(False)
    plt.title(i[1], fontsize=20, color='black')
    plt.tight_layout(pad=5.0)
    plt.grid(b=None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# Select categorical variables
categ = data.select_dtypes(include=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 20))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("crest_r", n_colors=7).as_hex()


# Loop columns
for i in (enumerate(categ)):
    plt.subplot(4, 2, i[0]+1)
    
    if data[i[1]].value_counts().count() > 2:
        ax = sns.countplot(y = i[1], data = data, order=data[i[1]].value_counts().index, palette=colors)
        pct = data[i[1]].value_counts(ascending=False, normalize=True).values * 100
        ax.bar_label(container=ax.containers[0], labels=list(map('{:.2f}%'.format,pct)), padding=3, size=12, color='black')
        ax.grid(False)
        ax.grid(b=None)
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.set_xticklabels('')
        plot_design()
        
    else:
        _, texts, pcts = plt.pie(
            data[i[1]].value_counts(), 
            labels=data[i[1]].value_counts().index, 
            colors= ['#00538F', '#6AADCC'],
            autopct='%1.1f%%', 
            wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
            startangle=50)
        for pcts in pcts:
          pcts.set_color('white')
        plt.title(i[1], fontsize=20, color='black')
# Out:
# C:\Users\vaibh\AppData\Local\Temp/ipykernel_51172/2703767664.py:26: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=None)
# C:\Users\vaibh\AppData\Local\Temp/ipykernel_51172/2857283910.py:8: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=None)
# C:\Users\vaibh\AppData\Local\Temp/ipykernel_51172/2703767664.py:26: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=None)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# Select categorical variables
categ = data.select_dtypes(include=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 20))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("crest_r", n_colors=7).as_hex()

data_final = data[data['Attrition_Flag'] == 'Existing Customer']

# Loop columns
for i in (enumerate(categ)):
    plt.subplot(4, 2, i[0]+1)
    
    if data[i[1]].value_counts().count() > 2:   
        ax = sns.countplot(y = i[1], data = data_final, order=data_final[i[1]].value_counts().index, palette=colors)
        pct = data_final[i[1]].value_counts(ascending=False, normalize=True).values * 100
        ax.bar_label(container=ax.containers[0], labels=list(map('{:.2f}%'.format,pct)), padding=3, size=12, color='black')
        ax.grid(False)
        ax.grid(b=None)
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.set_xticklabels('')
        plot_design()
    else:
        _, texts, pcts = plt.pie(
            data_final[i[1]].value_counts(), 
            labels=data_final[i[1]].value_counts().index, 
            colors= ['#00538F', '#6AADCC'],
            autopct='%1.1f%%', 
            wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
            startangle=50)
        for pcts in pcts:
          pcts.set_color('white')
        plt.title(i[1], fontsize=20, color='black')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# Select categorical variables
categ = data.select_dtypes(include=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 20))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("crest_r", n_colors=7).as_hex()

data_final = data[data['Attrition_Flag'] == 'Attrited Customer']

# Loop columns
for i in (enumerate(categ)):
    plt.subplot(4, 2, i[0]+1)
    
    if data[i[1]].value_counts().count() > 2:   
        ax = sns.countplot(y = i[1], data = data_final, order=data_final[i[1]].value_counts().index, palette=colors)
        pct = data_final[i[1]].value_counts(ascending=False, normalize=True).values * 100
        ax.bar_label(container=ax.containers[0], labels=list(map('{:.2f}%'.format,pct)), padding=3, size=12, color='black')
        ax.grid(False)
        ax.grid(b=None)
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.set_xticklabels('')
        plot_design()
    else:
        _, texts, pcts = plt.pie(
            data_final[i[1]].value_counts(), 
            labels=data_final[i[1]].value_counts().index, 
            colors= ['#00538F', '#6AADCC'],
            autopct='%1.1f%%', 
            wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
            startangle=50)
        for pcts in pcts:
          pcts.set_color('white')
        plt.title(i[1], fontsize=20, color='black')

# %%
numeric = data.select_dtypes(exclude=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 35))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("dark", n_colors=14).as_hex()

# Loop columns
for i in (enumerate(numeric)):
    plt.subplot(7, 2, i[0]+1)
    sns.kdeplot(x = i[1], data = data, color=colors[i[0]], fill=True)
    plt.grid(b=None)
    plot_design()

# %%
data_final = data[data['Attrition_Flag'] == 'Attrited Customer']
numeric = data_final.select_dtypes(exclude=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 35))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("dark", n_colors=14).as_hex()

# Loop columns
for i in (enumerate(numeric)):
    plt.subplot(7, 2, i[0]+1)
    sns.kdeplot(x = i[1], data = data_final, color=colors[i[0]], fill=True)
    plt.grid(b=None)
    plot_design()

# %%
data_final = data[data['Attrition_Flag'] == 'Attrited Customer']
data_final = data_final[data_final.select_dtypes(exclude=object).columns]
data_temp = data[data['Attrition_Flag'] == 'Existing Customer']
data_temp = data_temp[data_temp.select_dtypes(exclude=object).columns]
temp1 = data_final.describe()
temp2 = data_temp.describe()
temp2.compare(temp1)
# Out:
#       Customer_Age              Dependent_count              Months_on_book  \
#               self        other            self        other           self
# count  8500.000000  1627.000000     8500.000000  1627.000000    8500.000000
# mean     46.262118    46.659496        2.335412     2.402581      35.880588
# std       8.081157     7.665652        1.303229     1.275010       8.021810
# min            NaN          NaN             NaN          NaN            NaN
# 25%            NaN          NaN        1.000000     2.000000      31.000000
# 50%      46.000000    47.000000             NaN          NaN            NaN
# 75%            NaN          NaN             NaN          NaN            NaN
# max      73.000000    68.000000             NaN          NaN            NaN
#
#                    Total_Relationship_Count               \
#              other                     self        other
# count  1627.000000              8500.000000  1627.000000
# ...

# %%
columns = ['Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Total_Revolving_Bal', 'Contacts_Count_12_mon', 'Avg_Utilization_Ratio', 'Total_Trans_Amt']
cat_col = data['Attrition_Flag'].replace(['Existing Customer', 'Attrited Customer'],[0,1])
data_temp = data
#data_temp['Attrition_Flag'] = data_temp['Attrition_Flag'].apply(lambda x: x.cat.codes)
data_temp['Attrition_Flag'] = cat_col.values
data_temp.corr()
# Out:
#                           Attrition_Flag  Customer_Age  Dependent_count  \
# Attrition_Flag                  1.000000      0.018203         0.018991
# Customer_Age                    0.018203      1.000000        -0.122254
# Dependent_count                 0.018991     -0.122254         1.000000
# Months_on_book                  0.013687      0.788912        -0.103062
# Total_Relationship_Count       -0.150005     -0.010931        -0.039076
# Months_Inactive_12_mon          0.152449      0.054361        -0.010768
# Contacts_Count_12_mon           0.204491     -0.018452        -0.040505
# Credit_Limit                   -0.023873      0.002476         0.068065
# Total_Revolving_Bal            -0.263053      0.014780        -0.002688
# Avg_Open_To_Buy                -0.000285      0.001151         0.068291
# Total_Amt_Chng_Q4_Q1           -0.131063     -0.062042        -0.035439
# Total_Trans_Amt                -0.168598     -0.046446         0.025046
# ...

# %%
data_temp['Attrition_Flag'] = data['Attrition_Flag'].astype('category')
data_temp
data_temp['Attrition_Flag'].cat.codes
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10122    0
# 10123    1
# 10124    1
# 10125    1
# 10126    1
# Length: 10127, dtype: int8

# %%
data_cor
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 240    Attrited Customer            53      F                2
# 416    Attrited Customer            42      F                2
# 429    Attrited Customer            58      F                4
# 467    Attrited Customer            43      F                2
# 640    Attrited Customer            53      M                1
# ...                  ...           ...    ...              ...
# 9988   Attrited Customer            46      F                3
# 10024  Attrited Customer            50      M                2
# 10048  Attrited Customer            48      M                4
# 10065  Attrited Customer            38      M                2
# 10119  Attrited Customer            55      F                3
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 240           Unknown        Married  Less than $40K          Blue
# 416          Graduate        Married  Less than $40K          Blue
# ...

# %%
# Select categorical variables
categ = data.select_dtypes(include=object).columns

# Visualize
fig, ax = plt.subplots(figsize =(20, 20))
fig.patch.set_facecolor('white')
mpl.rcParams['font.family'] = 'Hiragino Kaku Gothic Pro'
mpl.rcParams['font.size'] = 12

colors = sns.color_palette("crest_r", n_colors=7).as_hex()



# Loop columns
for i in (enumerate(categ)):
    plt.subplot(4, 2, i[0]+1)
    
    if data[i[1]].value_counts().count() > 2:   
        ax = sns.countplot(y = i[1], data = data_cor, order=data_cor[i[1]].value_counts().index, palette=colors)
        pct = data_cor[i[1]].value_counts(ascending=False, normalize=True).values * 100
        ax.bar_label(container=ax.containers[0], labels=list(map('{:.2f}%'.format,pct)), padding=3, size=12, color='black')
        ax.grid(False)
        ax.grid(b=None)
        ax.xaxis.set_ticks_position('none')
        ax.yaxis.set_ticks_position('none')
        ax.set_xticklabels('')
        plot_design()
    else:
        _, texts, pcts = plt.pie(
            data_cor[i[1]].value_counts(), 
            labels=data_cor[i[1]].value_counts().index, 
            colors= ['#00538F', '#6AADCC'],
            autopct='%1.1f%%', 
            wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
            startangle=50)
        for pcts in pcts:
          pcts.set_color('white')
        plt.title(i[1], fontsize=20, color='black')
